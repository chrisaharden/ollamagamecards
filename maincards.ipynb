# %%
import json
import ollama
import asyncio
import generate_card_pdf


# New function to generate a game PDF with an array of words
def generate_game_pdf(words: list[str]) -> str:
    # This is a placeholder implementation
    # In a real scenario, this function would generate a PDF
    my_nouns = ["apple", "banana", "car", "dog", "elephant"]
    generate_card_pdf.generate_card_pdf(my_nouns) #TO DO replace with words param
    return json.dumps({"status": "PDF generated", "words": words})


async def run(model: str):
    client = ollama.AsyncClient()
    # Initialize conversation with a user query
    messages = [{'role': 'user', 'content': 'Can you generate a word game PDF with the following words: cat, dog, bird?'}]

    # First API call: Send the query and function description to the model
    response = await client.chat(
        model=model,
        messages=messages,
        tools=[
            {
                'type': 'function',
                'function': {
                    'name': 'generate_game_pdf',
                    'description': 'Generate a PDF with a word game using the provided words',
                    'parameters': {
                        'type': 'object',
                        'properties': {
                            'words': {
                                'type': 'array',
                                'items': {'type': 'string'},
                                'description': 'An array of words to be used in the game',
                            },
                        },
                        'required': ['words'],
                    },
                },
            },
        ],
    )

    # Add the model's response to the conversation history
    messages.append(response['message'])

    # Check if the model decided to use the provided function
    if not response['message'].get('tool_calls'):
        print("The model didn't use the function. Its response was:")
        print(response['message']['content'])
        return

    # Process function calls made by the model
    if response['message'].get('tool_calls'):
        available_functions = {
            'generate_game_pdf': generate_game_pdf,
        }
        for tool in response['message']['tool_calls']:
            function_to_call = available_functions[tool['function']['name']]
            function_args = tool['function']['arguments']
            function_response = function_to_call(function_args['words'])
            # Add function response to the conversation
            messages.append(
                {
                    'role': 'tool',
                    'content': function_response,
                }
            )

    # Second API call: Get final response from the model
    final_response = await client.chat(model=model, messages=messages)
    print(final_response['message']['content'])


# Run the async function
# asyncio.run(run('mistral'))
# asyncio.run(run('llama3.1'))

# CH: use this in a python script for asynchronous processes:
# asyncio.run(run('llama3.1'))

# CH: Use this when you are in the jupyter notebook:
await run('llama3.1')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 86
#      75     print(final_response['message']['content'])
#      78 # Run the async function
#      79 # asyncio.run(run('mistral'))
#      80 # asyncio.run(run('llama3.1'))
#    (...)
#      84
#      85 # CH: Use this when you are in the jupyter notebook:
# ---> 86 await run('llama3.1')
#
# Cell In[1], line 64, in run(model)
#      62 function_to_call = available_functions[tool['function']['name']]
#      63 function_args = tool['function']['arguments']
# ---> 64 function_response = function_to_call(function_args['words'])
#      65 # Add function response to the conversation
#      66 messages.append(
#      67     {
#      68         'role': 'tool',
#      69         'content': function_response,
#      70     }
#      71 )
#
# Cell In[1], line 12, in generate_game_pdf(words)
#       8 def generate_game_pdf(words: list[str]) -> str:
#       9     # This is a placeholder implementation
#      10     # In a real scenario, this function would generate a PDF
#      11     my_nouns = ["apple", "banana", "car", "dog", "elephant"]
# ---> 12     generate_card_pdf(my_nouns) #TO DO replace with words param
#      13     return json.dumps({"status": "PDF generated", "words": words})
#
# TypeError: 'module' object is not callable. Did you mean: 'generate_card_pdf.generate_card_pdf(...)'?
